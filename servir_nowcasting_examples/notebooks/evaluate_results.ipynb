# %% [markdown]
# # Model Evaluation
#
# This notebook goes over how to evaluate the results from the nowcasts that have been produced. It is assumed that the outputs from individual models have been saved in advance.
#
# Author: Akshay Aravamudan (aaravamudan2014@my.fit.edu)
#
# Last Edited: Jan 21, 2025

# %% [markdown]
# ## Imports

# %%
from servir.utils.evaluation import evaluation
from servir.utils.data_provider import IMERGDataModule
import numpy as np
from servir.utils.evaluation import csi_boxplot, rapsd_boxplot

# %% [markdown]
# ## Initialize parameters

# %%
# event id for which the data was downloaded
event_id = 1

# location of the h5 file that was generated after downloading the data
h5_dataset_location = '../../data/events/'+str(event_id)+'.h5'

# as of now, we do not have IR data, so we set it None
ir_h5_dataset_location = None

# this string is used to determine the kind of dataloader we need to use
# for processing individual events, we recommend the user to keep this fixed
dataset_type = 'wa'

# threshold to be used for critical success index
thr_list = [2,4,8]
get_crps = False

# %% [markdown]
# ## Initialize data provider

# %%
data_provider =  IMERGDataModule(
        forecast_steps = 12,
        history_steps = 12,
        imerg_filename = h5_dataset_location,
        ir_filename = ir_h5_dataset_location,
        batch_size = 32,
        image_shape = (360, 516),
        normalize_data=False,
        dataset = dataset_type)

data_loader = data_provider.test_dataloader()
# Out:
# original shape (97, 360, 516)
# Precipitation Dataset input shape:  (74, 12, 1, 360, 516)
# Precipitation Dataset output shape:  (74, 12, 1, 360, 516)

# %% [markdown]
# ## Generate metrics for each model
#
# For each of the models, we generate the predictions and metrics -- Critical Success Index (CSI), RAPSD (Radially Averaged Power Spectral Index) and CRPS (Continuous Ranked Probability Score) and save them in a location for processing later. They are being saved because it typically takes some time to generate these metrics and it is better to load them up and process them on the fly.

# %%
# model_type = 'convlstm'
# model_config_location = 'configs/wa_imerg/ConvLSTM.py'
# model_save_location = 'temp/imerg_only_mse_params.pth'
# metrics_output_location = '' 
# use_gpu = False
# convlstm_crps, convlstm_psd_dict, convlstm_csi_dict = evaluation(data_loader, thr_list, model_type, model_config_location, model_save_location, use_gpu, use_ensemble=False, event_name = event_id)

model_type = 'steps'
model_config_location = '../configs/wa_imerg/PySTEPS.py'
model_save_location = ''
use_gpu = False
steps_crps, steps_psd_dict, steps_csi_dict = evaluation( data_loader, thr_list, model_type, model_config_location, model_save_location, use_gpu, use_ensemble=False, event_name = event_id)

model_type = 'lagrangian'
model_config_location = '../configs/wa_imerg/lagrangian_persistence.py'
model_save_location = ''
use_gpu = False
lagrangian_crps, lagrangian_psd_dict, lagrangian_csi_dict = evaluation(data_loader, thr_list, model_type, model_config_location, model_save_location, use_gpu, use_ensemble=False, event_name = event_id)

model_type = 'naive'
model_config_location = '../configs/wa_imerg/naive_persistence.py'
model_save_location = ''
use_gpu = False
naive_crps, naive_psd_dict, naive_csi_dict = evaluation(data_loader, thr_list, model_type, model_config_location, model_save_location, use_gpu, use_ensemble=False, event_name = event_id)
# Out:
# loading config from ../configs/wa_imerg/PySTEPS.py ...
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# starting predictions for batch 0
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.997119      | 0.992680      |
# -----------------------------------------
# | 2     | 0.987422      | 0.964369      |
# -----------------------------------------
# | 3     | 0.968031      | 0.882592      |
# -----------------------------------------
# | 4     | 0.871580      | 0.650201      |
# -----------------------------------------
# | 5     | 0.588731      | 0.231399      |
# -----------------------------------------
# | 6     | 0.305103      | 0.081335      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.268492     | -0.272157    | 0.072994     |
# ------------------------------------------------------
# | 2     | 1.407482     | -0.425411    | 0.143085     |
# ------------------------------------------------------
# | 3     | 1.547822     | -0.598938    | 0.200864     |
# ------------------------------------------------------
# | 4     | 1.169706     | -0.342053    | 0.460682     |
# ------------------------------------------------------
# | 5     | 0.651133     | -0.105994    | 0.803775     |
# ------------------------------------------------------
# | 6     | 0.309057     | -0.012959    | 0.952239     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.993808      | 0.993235      |
# -----------------------------------------
# | 2     | 0.955171      | 0.952065      |
# -----------------------------------------
# | 3     | 0.933079      | 0.924070      |
# -----------------------------------------
# | 4     | 0.838787      | 0.745655      |
# -----------------------------------------
# | 5     | 0.562138      | 0.339046      |
# -----------------------------------------
# | 6     | 0.251642      | 0.085009      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.544516     | 0.452091     | 0.099111     |
# ------------------------------------------------------
# | 2     | 0.522382     | 0.453101     | 0.263921     |
# ------------------------------------------------------
# | 3     | 0.547669     | 0.413052     | 0.327555     |
# ------------------------------------------------------
# | 4     | 0.719687     | 0.141991     | 0.538943     |
# ------------------------------------------------------
# | 5     | 0.543197     | 0.033694     | 0.826574     |
# ------------------------------------------------------
# | 6     | 0.245816     | 0.023151     | 0.967561     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.997069      | 0.990328      |
# -----------------------------------------
# | 2     | 0.962009      | 0.903004      |
# -----------------------------------------
# | 3     | 0.888274      | 0.832192      |
# -----------------------------------------
# | 4     | 0.723180      | 0.618416      |
# -----------------------------------------
# | 5     | 0.482434      | 0.269709      |
# -----------------------------------------
# | 6     | 0.240283      | 0.035225      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.647383     | -0.652226    | 0.057998     |
# ------------------------------------------------------
# | 2     | 1.251830     | -0.301267    | 0.260334     |
# ------------------------------------------------------
# | 3     | 0.706547     | 0.204584     | 0.449599     |
# ------------------------------------------------------
# | 4     | 0.578506     | 0.200052     | 0.676698     |
# ------------------------------------------------------
# | 5     | 0.459191     | 0.048180     | 0.874915     |
# ------------------------------------------------------
# | 6     | 0.243855     | -0.014866    | 0.970596     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.992096      | 0.993469      |
# -----------------------------------------
# | 2     | 0.939671      | 0.911648      |
# -----------------------------------------
# | 3     | 0.861634      | 0.760846      |
# -----------------------------------------
# | 4     | 0.722566      | 0.545615      |
# -----------------------------------------
# | 5     | 0.435694      | 0.185854      |
# -----------------------------------------
# | 6     | 0.203107      | 0.035116      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.411487     | 0.585234     | 0.101749     |
# ------------------------------------------------------
# | 2     | 0.709479     | 0.244971     | 0.331655     |
# ------------------------------------------------------
# | 3     | 0.799976     | 0.071559     | 0.506228     |
# ------------------------------------------------------
# | 4     | 0.687015     | 0.049201     | 0.690464     |
# ------------------------------------------------------
# | 5     | 0.437832     | -0.004907    | 0.900084     |
# ------------------------------------------------------
# | 6     | 0.204407     | -0.006401    | 0.979136     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.998053      | 0.989306      |
# -----------------------------------------
# | 2     | 0.982187      | 0.910506      |
# -----------------------------------------
# | 3     | 0.972935      | 0.813906      |
# -----------------------------------------
# | 4     | 0.910426      | 0.610341      |
# -----------------------------------------
# | 5     | 0.727798      | 0.246097      |
# -----------------------------------------
# | 6     | 0.432583      | 0.050531      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.878916     | -0.882582    | 0.029324     |
# ------------------------------------------------------
# | 2     | 1.653641     | -0.683632    | 0.137140     |
# ------------------------------------------------------
# | 3     | 1.580623     | -0.624593    | 0.180461     |
# ------------------------------------------------------
# | 4     | 1.288029     | -0.414755    | 0.376414     |
# ------------------------------------------------------
# | 5     | 0.863450     | -0.186387    | 0.673774     |
# ------------------------------------------------------
# | 6     | 0.454969     | -0.051749    | 0.900386     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.997405      | 0.995587      |
# -----------------------------------------
# | 2     | 0.981501      | 0.963373      |
# -----------------------------------------
# | 3     | 0.953711      | 0.928828      |
# -----------------------------------------
# | 4     | 0.865498      | 0.791528      |
# -----------------------------------------
# | 5     | 0.618347      | 0.454647      |
# -----------------------------------------
# | 6     | 0.303548      | 0.118928      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.849166     | 0.148625     | 0.071197     |
# ------------------------------------------------------
# | 2     | 0.980728     | 0.000787     | 0.191458     |
# ------------------------------------------------------
# | 3     | 0.750575     | 0.212996     | 0.293823     |
# ------------------------------------------------------
# | 4     | 0.719099     | 0.169149     | 0.493695     |
# ------------------------------------------------------
# | 5     | 0.545971     | 0.117047     | 0.780503     |
# ------------------------------------------------------
# | 6     | 0.294592     | 0.029505     | 0.952401     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.995441      | 0.998527      |
# -----------------------------------------
# | 2     | 0.970348      | 0.982302      |
# -----------------------------------------
# | 3     | 0.928293      | 0.923025      |
# -----------------------------------------
# | 4     | 0.798068      | 0.755676      |
# -----------------------------------------
# | 5     | 0.419932      | 0.329154      |
# -----------------------------------------
# | 6     | 0.163226      | 0.066983      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.161206     | 0.838056     | 0.052038     |
# ------------------------------------------------------
# | 2     | 0.293938     | 0.697080     | 0.173305     |
# ------------------------------------------------------
# | 3     | 0.516774     | 0.443307     | 0.333314     |
# ------------------------------------------------------
# | 4     | 0.537024     | 0.327094     | 0.569421     |
# ------------------------------------------------------
# | 5     | 0.342023     | 0.185527     | 0.891800     |
# ------------------------------------------------------
# | 6     | 0.156461     | 0.041444     | 0.985741     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.992794      | 0.985449      |
# -----------------------------------------
# | 2     | 0.984099      | 0.943295      |
# -----------------------------------------
# | 3     | 0.959140      | 0.865479      |
# -----------------------------------------
# | 4     | 0.890529      | 0.657616      |
# -----------------------------------------
# | 5     | 0.661227      | 0.175574      |
# -----------------------------------------
# | 6     | 0.347930      | 0.011702      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.006038     | -0.013340    | 0.119822     |
# ------------------------------------------------------
# | 2     | 1.671337     | -0.698342    | 0.127133     |
# ------------------------------------------------------
# | 3     | 1.495232     | -0.558930    | 0.234611     |
# ------------------------------------------------------
# | 4     | 1.224157     | -0.374640    | 0.421794     |
# ------------------------------------------------------
# | 5     | 0.755608     | -0.142736    | 0.742504     |
# ------------------------------------------------------
# | 6     | 0.359150     | -0.032247    | 0.937033     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.994547      | 0.988323      |
# -----------------------------------------
# | 2     | 0.973921      | 0.961483      |
# -----------------------------------------
# | 3     | 0.937880      | 0.882134      |
# -----------------------------------------
# | 4     | 0.803052      | 0.723419      |
# -----------------------------------------
# | 5     | 0.539149      | 0.341308      |
# -----------------------------------------
# | 6     | 0.366394      | 0.085883      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.067667     | -0.073521    | 0.104011     |
# ------------------------------------------------------
# | 2     | 0.728711     | 0.251775     | 0.219580     |
# ------------------------------------------------------
# | 3     | 0.918286     | 0.020892     | 0.346884     |
# ------------------------------------------------------
# | 4     | 0.625469     | 0.221136     | 0.581156     |
# ------------------------------------------------------
# | 5     | 0.500669     | 0.071373     | 0.840062     |
# ------------------------------------------------------
# | 6     | 0.379593     | -0.036023    | 0.929856     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.994811      | 0.984108      |
# -----------------------------------------
# | 2     | 0.976940      | 0.935847      |
# -----------------------------------------
# | 3     | 0.955648      | 0.878221      |
# -----------------------------------------
# | 4     | 0.890133      | 0.698442      |
# -----------------------------------------
# | 5     | 0.623941      | 0.312519      |
# -----------------------------------------
# | 6     | 0.287765      | 0.073564      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.527244     | -0.535211    | 0.085944     |
# ------------------------------------------------------
# | 2     | 1.374780     | -0.407231    | 0.195008     |
# ------------------------------------------------------
# | 3     | 1.341720     | -0.403990    | 0.269409     |
# ------------------------------------------------------
# | 4     | 1.222961     | -0.373908    | 0.422647     |
# ------------------------------------------------------
# | 5     | 0.700478     | -0.122667    | 0.775570     |
# ------------------------------------------------------
# | 6     | 0.290665     | -0.010079    | 0.957652     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.993883      | 0.991977      |
# -----------------------------------------
# | 2     | 0.972634      | 0.968756      |
# -----------------------------------------
# | 3     | 0.919520      | 0.902374      |
# -----------------------------------------
# | 4     | 0.820040      | 0.749873      |
# -----------------------------------------
# | 5     | 0.515541      | 0.307674      |
# -----------------------------------------
# | 6     | 0.226162      | 0.046749      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.653788     | 0.342188     | 0.103774     |
# ------------------------------------------------------
# | 2     | 0.562922     | 0.421240     | 0.210724     |
# ------------------------------------------------------
# | 3     | 0.581090     | 0.368051     | 0.365455     |
# ------------------------------------------------------
# | 4     | 0.626234     | 0.236336     | 0.556094     |
# ------------------------------------------------------
# | 5     | 0.486126     | 0.057056     | 0.855469     |
# ------------------------------------------------------
# | 6     | 0.227211     | -0.004637    | 0.974079     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.990603      | 0.978387      |
# -----------------------------------------
# | 2     | 0.964917      | 0.927748      |
# -----------------------------------------
# | 3     | 0.918330      | 0.808003      |
# -----------------------------------------
# | 4     | 0.799970      | 0.601118      |
# -----------------------------------------
# | 5     | 0.527011      | 0.199671      |
# -----------------------------------------
# | 6     | 0.258740      | -0.008857     |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.144568     | -0.155426    | 0.135108     |
# ------------------------------------------------------
# | 2     | 1.011353     | -0.048124    | 0.262250     |
# ------------------------------------------------------
# | 3     | 1.125397     | -0.225483    | 0.385623     |
# ------------------------------------------------------
# | 4     | 0.886251     | -0.107856    | 0.596540     |
# ------------------------------------------------------
# | 5     | 0.569785     | -0.081164    | 0.847054     |
# ------------------------------------------------------
# | 6     | 0.263222     | -0.017321    | 0.965802     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.975311      | 0.970612      |
# -----------------------------------------
# | 2     | 0.954826      | 0.899668      |
# -----------------------------------------
# | 3     | 0.894203      | 0.816915      |
# -----------------------------------------
# | 4     | 0.732752      | 0.573094      |
# -----------------------------------------
# | 5     | 0.467396      | 0.239710      |
# -----------------------------------------
# | 6     | 0.182086      | 0.041057      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.587714     | 0.397409     | 0.202649     |
# ------------------------------------------------------
# | 2     | 1.084846     | -0.136171    | 0.294397     |
# ------------------------------------------------------
# | 3     | 0.816938     | 0.086406     | 0.445987     |
# ------------------------------------------------------
# | 4     | 0.675519     | 0.078106     | 0.678417     |
# ------------------------------------------------------
# | 5     | 0.454687     | 0.027191     | 0.883721     |
# ------------------------------------------------------
# | 6     | 0.180598     | 0.008172     | 0.983250     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.998858      | 0.974071      |
# -----------------------------------------
# | 2     | 0.980338      | 0.915030      |
# -----------------------------------------
# | 3     | 0.952461      | 0.815829      |
# -----------------------------------------
# | 4     | 0.856453      | 0.585666      |
# -----------------------------------------
# | 5     | 0.648911      | 0.237794      |
# -----------------------------------------
# | 6     | 0.328578      | 0.042931      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 1.906632     | -0.908811    | 0.019931     |
# ------------------------------------------------------
# | 2     | 1.637545     | -0.670388    | 0.146418     |
# ------------------------------------------------------
# | 3     | 1.460088     | -0.532964    | 0.257786     |
# ------------------------------------------------------
# | 4     | 1.129717     | -0.319065    | 0.489244     |
# ------------------------------------------------------
# | 5     | 0.737036     | -0.135806    | 0.753816     |
# ------------------------------------------------------
# | 6     | 0.337960     | -0.028554    | 0.944092     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# extrapolation:          semilagrangian
# bandpass filter:        gaussian
# decomposition:          fft
# noise generator:        nonparametric
# noise adjustment:       no
# velocity perturbator:   bps
# conditional statistics: no
# precip. mask method:    incremental
# probability matching:   cdf
# FFT method:             numpy
# domain:                 spatial
#
# Parameters
# ----------
# number of time steps:     12
# ensemble size:            1
# parallel threads:         1
# number of cascade levels: 6
# order of the AR(p) model: 2
# velocity perturbations, parallel:      10.88,0.23,-7.68
# velocity perturbations, perpendicular: 5.76,0.31,-2.72
# precip. intensity threshold: -10.0
# ************************************************
# * Correlation coefficients for cascade levels: *
# ************************************************
# -----------------------------------------
# | Level |     Lag-1     |     Lag-2     |
# -----------------------------------------
# | 1     | 0.985060      | 0.982595      |
# -----------------------------------------
# | 2     | 0.926506      | 0.880356      |
# -----------------------------------------
# | 3     | 0.841782      | 0.792751      |
# -----------------------------------------
# | 4     | 0.650482      | 0.538027      |
# -----------------------------------------
# | 5     | 0.408195      | 0.256101      |
# -----------------------------------------
# | 6     | 0.180124      | 0.045683      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.578090     | 0.413142     | 0.156829     |
# ------------------------------------------------------
# | 2     | 0.782921     | 0.154975     | 0.371734     |
# ------------------------------------------------------
# | 3     | 0.598683     | 0.288791     | 0.516818     |
# ------------------------------------------------------
# | 4     | 0.520921     | 0.199177     | 0.744304     |
# ------------------------------------------------------
# | 5     | 0.364369     | 0.107367     | 0.907618     |
# ------------------------------------------------------
# | 6     | 0.177660     | 0.013683     | 0.983552     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# Computing STEPS nowcast
# -----------------------
#
# Inputs
# ------
# input dimensions: 360x516
# km/pixel:         10
# time step:        30 minutes
#
# Methods
# -------
# ...
# -----------------------------------------
# | 6     | 0.136932      | 0.031583      |
# -----------------------------------------
# ****************************************
# * AR(p) parameters for cascade levels: *
# ****************************************
# ------------------------------------------------------
# | Level |    Phi-1     |    Phi-2     |    Phi-0     |
# ------------------------------------------------------
# | 1     | 0.945802     | 0.024116     | 0.246301     |
# ------------------------------------------------------
# | 2     | 0.930049     | 0.035168     | 0.265925     |
# ------------------------------------------------------
# | 3     | 1.023192     | -0.101725    | 0.368863     |
# ------------------------------------------------------
# | 4     | 0.844959     | -0.064203    | 0.606686     |
# ------------------------------------------------------
# | 5     | 0.524663     | -0.025706    | 0.858991     |
# ------------------------------------------------------
# | 6     | 0.135141     | 0.013078     | 0.990496     |
# ------------------------------------------------------
# Starting nowcast computation.
# Computing nowcast for time step 1... done.
# Computing nowcast for time step 2... done.
# Computing nowcast for time step 3... done.
# Computing nowcast for time step 4... done.
# Computing nowcast for time step 5... done.
# Computing nowcast for time step 6... done.
# Computing nowcast for time step 7... done.
# Computing nowcast for time step 8... done.
# Computing nowcast for time step 9... done.
# Computing nowcast for time step 10... done.
# Computing nowcast for time step 11... done.
# Computing nowcast for time step 12... done.
# (12, 360, 516)
# total errored out =  0
# loading config from ../configs/wa_imerg/lagrangian_persistence.py ...
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# starting predictions for batch 0
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# starting predictions for batch 1
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# starting predictions for batch 2
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# (12, 360, 516)
# total errored out =  0
# loading config from ../configs/wa_imerg/naive_persistence.py ...
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# /volume/NFS/aa3328/miniconda3/envs/tito_env/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:285: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   return collate([torch.as_tensor(b) for b in batch], collate_fn_map=collate_fn_map)
# starting predictions for batch 0
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.01147770881652832  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.003256082534790039  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0030753612518310547  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026311874389648438  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002401590347290039  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002414226531982422  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026483535766601562  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0030701160430908203  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026702880859375  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023069381713867188  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0027251243591308594  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0022559165954589844  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0024178028106689453  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002721071243286133  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002599954605102539  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025970935821533203  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002640962600708008  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002764463424682617  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0024251937866210938  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023813247680664062  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0028595924377441406  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002296924591064453  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002336740493774414  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0022733211517333984  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0028634071350097656  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002338409423828125  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0033981800079345703  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026750564575195312  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002333402633666992  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0024170875549316406  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.003265857696533203  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0024051666259765625  seconds
# (12, 360, 516)
# starting predictions for batch 1
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0022644996643066406  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0027244091033935547  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026466846466064453  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002384662628173828  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0027277469635009766  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002300262451171875  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002347707748413086  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023665428161621094  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002165079116821289  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025243759155273438  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002218961715698242  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025975704193115234  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.003406047821044922  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023050308227539062  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025818347930908203  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023756027221679688  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002869129180908203  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0028121471405029297  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026750564575195312  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0022840499877929688  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002205371856689453  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025599002838134766  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002176046371459961  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.003209829330444336  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0023910999298095703  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002655029296875  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0025713443756103516  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002901315689086914  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0027551651000976562  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0021953582763671875  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0022907257080078125  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0026502609252929688  seconds
# (12, 360, 516)
# starting predictions for batch 2
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0029730796813964844  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002305746078491211  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002183675765991211  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0021653175354003906  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0038192272186279297  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002745389938354492  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002126932144165039  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.002386331558227539  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.003151416778564453  seconds
# (12, 360, 516)
# The shape of the resulting array is:  (12, 360, 516)
# Advecting the radar rainfall fields took  0.0021719932556152344  seconds
# (12, 360, 516)
# total errored out =  0

# %% [markdown]
# ### Load saved metrics
#
# Load the saved metrics for CSI, RAPSD and CRPS and visualize the outputs

# %% [markdown]
# ### CSI

# %%
event_id = 1

thr = 4

# convlstm_csi = np.load('results/convlstm_'+str(thr)+'_'+str(event_id)+'_csi.npy', allow_pickle=True).item()
steps_csi = np.load('results/steps_'+str(thr)+'_'+str(event_id)+'_csi.npy', allow_pickle=True).item()
lagrangian_csi = np.load('results/lagrangian_'+str(thr)+'_'+str(event_id)+'_csi.npy', allow_pickle=True).item()
naive_csi = np.load('results/naive_'+str(thr)+'_'+str(event_id)+'_csi.npy', allow_pickle=True).item()

csi_boxplot([steps_csi, lagrangian_csi, naive_csi], [ 'steps', 'lagrangian', 'naive'], thr=thr)

# %% [markdown]
# ## RAPSD

# %%
import numpy as np
from servir.utils.evaluation import rapsd_boxplot

event_id = 1

resolution = 11
# convlstm_rapsd = np.load('results/convlstm_'+str(event_id)+'_rapsd.npy', allow_pickle=True).item()
steps_rapsd  = np.load('results/steps_'+str(event_id)+'_rapsd.npy', allow_pickle=True).item()
lagrangian_rapsd  = np.load('results/lagrangian_'+str(event_id)+'_rapsd.npy', allow_pickle=True).item()
naive_rapsd  = np.load('results/naive_'+str(event_id)+'_rapsd.npy', allow_pickle=True).item()
gt_rapsd  = np.load('results/gt_'+str(event_id)+'_rapsd.npy', allow_pickle=True).item()

rapsd_boxplot([steps_rapsd, lagrangian_rapsd, naive_rapsd, gt_rapsd], ['steps', 'lagrangian', 'naive', 'gt'], s=resolution)
